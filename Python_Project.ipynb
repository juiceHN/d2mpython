# %%
import pandas as pd
fhand=pd.read_csv('sales.csv')
#Look at the first rows of the document
fhand.head()
# Out:
#          Order ID  Order Date  Order Year  Order Quarter   Ship Date  \
# 0  CA-2018-152156  08/11/2018        2018              3  11/11/2018
# 1  CA-2018-152156  08/11/2018        2018              3  11/11/2018
# 2  CA-2018-138688  12/06/2018        2018              4  16/06/2018
# 3  US-2017-108966  11/10/2017        2017              4  18/10/2017
# 4  US-2017-108966  11/10/2017        2017              4  18/10/2017
#
#         Ship Mode Customer ID    Customer Name    Segment        Country  ...  \
# 0    Second Class    CG-12520      Claire Gute   Consumer  United States  ...
# 1    Second Class    CG-12520      Claire Gute   Consumer  United States  ...
# 2    Second Class    DV-13045  Darrin Van Huff  Corporate  United States  ...
# 3  Standard Class    SO-20335   Sean O'Donnell   Consumer  United States  ...
# 4  Standard Class    SO-20335   Sean O'Donnell   Consumer  United States  ...
#
#   Postal Code Region       Product ID         Category Sub-Category  \
# ...

# %%
#Global overview of the data
fhand.shape
# Out:
# (9994, 22)

# %%
#Global overview of the data
fhand.dtypes
# Out:
# Order ID          object
# Order Date        object
# Order Year         int64
# Order Quarter      int64
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code      float64
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %%
#Global overview of the data
fhand.describe()
# Out:
#         Order Year  Order Quarter   Postal Code         Sales     Quantity  \
# count  9994.000000    9994.000000   9983.000000   9994.000000  9994.000000
# mean   2017.722233       2.694617  55245.233297    229.858001     3.789574
# std       1.123555       1.107635  32038.715955    623.245101     2.225110
# min    2016.000000       1.000000   1040.000000      0.444000     1.000000
# 25%    2017.000000       2.000000  23223.000000     17.280000     2.000000
# 50%    2018.000000       3.000000  57103.000000     54.490000     3.000000
# 75%    2019.000000       4.000000  90008.000000    209.940000     5.000000
# max    2019.000000       4.000000  99301.000000  22638.480000    14.000000
#
#           Discount       Profit
# count  9994.000000  9994.000000
# mean      0.156203    28.656896
# std       0.206452   234.260108
# min       0.000000 -6599.978000
# 25%       0.000000     1.728750
# 50%       0.200000     8.666500
# 75%       0.200000    29.364000
# ...

# %%
#Rename a column
fhand.rename(columns={'Sub-Category':'SubCategory'},inplace=True)
fhand.head()
# Out:
#          Order ID  Order Date  Order Year  Order Quarter   Ship Date  \
# 0  CA-2018-152156  08/11/2018        2018              3  11/11/2018
# 1  CA-2018-152156  08/11/2018        2018              3  11/11/2018
# 2  CA-2018-138688  12/06/2018        2018              4  16/06/2018
# 3  US-2017-108966  11/10/2017        2017              4  18/10/2017
# 4  US-2017-108966  11/10/2017        2017              4  18/10/2017
#
#         Ship Mode Customer ID    Customer Name    Segment        Country  ...  \
# 0    Second Class    CG-12520      Claire Gute   Consumer  United States  ...
# 1    Second Class    CG-12520      Claire Gute   Consumer  United States  ...
# 2    Second Class    DV-13045  Darrin Van Huff  Corporate  United States  ...
# 3  Standard Class    SO-20335   Sean O'Donnell   Consumer  United States  ...
# 4  Standard Class    SO-20335   Sean O'Donnell   Consumer  United States  ...
#
#   Postal Code Region       Product ID         Category SubCategory  \
# ...

# %%
#Average quantities sold per subcategory
fhand.SubCategory.unique()
qty_mean_subcat = fhand.groupby('SubCategory').Quantity.mean()
print(type(qty_mean_subcat))
qty_mean_subcat.sort_values(ascending=False)
# Out:
# <class 'pandas.core.series.Series'>
# SubCategory
# Fasteners      4.211982
# Binders        3.922521
# Tables         3.890282
# Labels         3.846154
# Accessories    3.840000
# Machines       3.826087
# Chairs         3.818476
# Bookcases      3.807018
# Paper          3.779562
# Art            3.768844
# Storage        3.732861
# Furnishings    3.723093
# Appliances     3.710300
# Phones         3.699663
# Envelopes      3.566929
# Copiers        3.441176
# Supplies       3.405263
# Name: Quantity, dtype: float64

# %%
#Average sales per subcategory
fhand.SubCategory.unique()
sales_mean_subcat = fhand.groupby('SubCategory').Sales.mean()
print(type(sales_mean_subcat))
sales_mean_subcat.sort_values(ascending=False)
# Out:
# <class 'pandas.core.series.Series'>
# SubCategory
# Copiers        2198.941618
# Machines       1645.553313
# Tables          648.794771
# Chairs          532.332420
# Bookcases       503.859633
# Phones          371.211534
# Storage         264.590553
# Supplies        245.650200
# Appliances      230.755710
# Accessories     215.974604
# Binders         133.560560
# Furnishings      95.825668
# Envelopes        64.867724
# Paper            57.284092
# Labels           34.303055
# Art              34.068834
# Fasteners        13.936774
# Name: Sales, dtype: float64

# %%
#Average discount per subcategory
fhand.SubCategory.unique()
discount_mean_subcat = fhand.groupby('SubCategory').Discount.mean()
print(type(discount_mean_subcat))
pourcentage_discount_mean_subcat = discount_mean_subcat*100
pourcentage_discount_mean_subcat.sort_values(ascending=False)
# Out:
# <class 'pandas.core.series.Series'>
# SubCategory
# Binders        37.229153
# Machines       30.608696
# Tables         26.128527
# Bookcases      21.114035
# Chairs         17.017828
# Appliances     16.652361
# Copiers        16.176471
# Phones         15.455568
# Furnishings    13.834901
# Fasteners       8.202765
# Envelopes       8.031496
# Accessories     7.845161
# Supplies        7.684211
# Paper           7.489051
# Art             7.487437
# Storage         7.470449
# Labels          6.868132
# Name: Discount, dtype: float64

# %%
#Visualize the repartition of sales per Subcategory
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sb
plt.figure(figsize=(16,7))
sb.barplot(data=fhand, x='SubCategory', y='Sales', ci=None)
#None removes error bars

# %%
#Adding the figures on the plot
plt.figure(figsize=(16,7))
chart=sb.barplot(data=fhand,x='SubCategory',y='Sales',ci=None)
def values_on_bars(chart):
    for p in chart.patches:
        chart.annonate(format(p.get_height(),'.2f'),
                      (p.get_x()+p.get_width()/2.,
                      p.get_height()),
                      ha='center',
                      va='center',
                      xytext=(0, 10),
                      textcoords='offset points')
values_on_bars(chart)
#It does not work????
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-85-c68bbbc4ebf4> in <module>
#      10                       xytext=(0, 10),
#      11                       textcoords='offset points')
# ---> 12 values_on_bars(chart)
#
# <ipython-input-85-c68bbbc4ebf4> in values_on_bars(chart)
#       3 def values_on_bars(chart):
#       4     for p in chart.patches:
# ----> 5         chart.annonate(format(p.get_height(),'.2f'),
#       6                       (p.get_x()+p.get_width()/2.,
#       7                       p.get_height()),
#
# AttributeError: 'AxesSubplot' object has no attribute 'annonate'

# %%
#Sales evolution per year
plt.figure(figsize=(16,7))
chart=sb.lineplot(data=fhand, x='Order Year', y='Sales')
chart.set_title('Total sales evolution per year')
chart.set_xlabel('Year')
chart.set_ylabel('Total Sales')
# Out:
# Text(0, 0.5, 'Total Sales')

# %%
#Yearly sales evolution per Category
by_year_cat_sales = fhand.groupby(['Order Year','Category']).Sales.sum().reset_index()

plt.figure(figsize=(10,7))
chart=sb.lineplot(data=by_year_cat_sales, x='Order Year',hue= 'Category',y='Sales',ci=None)
chart.set_title('Total Sales evolution per year per Category')
chart.set_xlabel('Year')
chart.set_ylabel('Total Sales')
# Out:
# Text(0, 0.5, 'Total Sales')

# %%
#Yearly sales evolution per Segment
by_year_segment_sales = fhand.groupby(['Order Year','Segment']).Sales.sum().reset_index()

plt.figure(figsize=(10,7))
chart=sb.lineplot(data=by_year_segment_sales, x='Order Year',hue= 'Segment',y='Sales',ci=None)
chart.set_title('Total Sales evolution per year per Segment')
chart.set_xlabel('Year')
chart.set_ylabel('Total Sales')
# Out:
# Text(0, 0.5, 'Total Sales')

# %%
#Yearly sales evolution per Region
by_year_region_sales = fhand.groupby(['Order Year','Region']).Sales.sum().reset_index()

plt.figure(figsize=(10,7))
chart=sb.lineplot(data=by_year_region_sales, x='Order Year',hue= 'Region',y='Sales',ci=None)
chart.set_title('Total Sales evolution per year per Region')
chart.set_xlabel('Year')
chart.set_ylabel('Total Sales')
# Out:
# Text(0, 0.5, 'Total Sales')

# %%
#Boxplot Discount per Subcategory
plt.figure(figsize=(16,6))
chart=sb.boxplot(data=fhand,x='SubCategory',y='Discount')
chart.set_title('Boxplot of Discount per Subcategory')
# Out:
# Text(0.5, 1.0, 'Boxplot of Discount per Subcategory')
